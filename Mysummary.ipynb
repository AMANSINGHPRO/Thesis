# %% [markdown]
# # Auto - SUM

# %%
import urllib.request
from bs4 import BeautifulSoup

# %%
articleURL = "http://fortune.com/2016/12/21/state-street-blockchain/"

# %%
page = urllib.request.urlopen(articleURL).read().decode('utf8','ignore')

# %%
soup = BeautifulSoup(page,"lxml")

# %%
soup
# Out:
# <!DOCTYPE html>
# <html data-react-checksum="1476636906" data-reactid="1" data-reactroot="" lang="en-us"><head data-reactid="2"><title data-react-helmet="true" data-reactid="3">State Street Is Testing Blockchain for Securities Lending | Fortune.com</title><meta charset="utf-8" data-react-helmet="true" data-reactid="4"/><meta data-react-helmet="true" data-reactid="5" http-equiv="'X-UA-Compatible', content='IE=edge'"/><meta data-react-helmet="true" data-reactid="6" http-equiv="'Content-Type', content='text/html; charset=utf-8'"/><meta content="State Street has tested a blockchain system that it hopes can be used to streamline the securities lending process." data-react-helmet="true" data-reactid="7" name="description"/><meta content="State Street, blockchain, bitcoin, digital currency, cybersecurity, securities lending, cryptocurrency, Euroclear, Emerging Technologies Center" data-react-helmet="true" data-reactid="8" name="keywords"/><meta content="State Street, blockchain, bitcoin, digital currency, cybersecurity, securities lending, cryptocurrency, Euroclear, Emerging Technologies Center" data-react-helmet="true" data-reactid="9" name="news_keywords"/><meta content="Fortune" data-react-helmet="true" data-reactid="10" name="og:site_name"/><meta content="en_US" data-react-helmet="true" data-reactid="11" property="og:locale"/><meta content="http://fortune.com/2016/12/21/state-street-blockchain/" data-react-helmet="true" data-reactid="12" property="og:url"/><meta content="State Street Is Testing Blockchain for Securities Lending" data-react-helmet="true" data-reactid="13" property="og:title"/><meta content="FORTUNE" data-react-helmet="true" data-reactid="14" property="og:author"/><meta content="FORTUNE" data-react-helmet="true" data-reactid="15" name="author"/><meta content="More and more financial firms are warming up to blockchain." data-react-helmet="true" data-reactid="16" property="og:description"/><meta content="https://fortunedotcom.files.wordpress.com/2016/05/gettyimages-167578473.jpg" data-react-helmet="true" data-reactid="17" property="og:image"/><meta content="859381007513473" data-react-helmet="true" data-reactid="18" property="fb:app_id"/><meta content="@fortunemagazine" data-react-helmet="true" data-reactid="19" name="twitter:site"/><meta content="State Street Is Testing Blockchain for Securities Lending" data-react-helmet="true" data-reactid="20" name="twitter:title"/><meta content="State Street Is Testing Blockchain for Securities Lending" data-react-helmet="true" data-reactid="21" name="twitter:description"/><meta content="summary_large_image" data-react-helmet="true" data-reactid="22" name="twitter:card"/><link data-react-helmet="true" data-reactid="23" href="http://fortune.com/2016/12/21/state-street-blockchain/" rel="canonical"/><link data-react-helmet="true" data-reactid="24" href="http://amp.timeinc.net/fortune/2016/12/21/state-street-blockchain/?source=dam" rel="amphtml"/><script data-react-helmet="true" data-reactid="25" type="application/ld+json">{"@context":"http://schema.org","@type":"NewsArticle","mainEntityOfPage":{"@type":"WebPage","@id":"http://fortune.com/2016/12/21/state-street-blockchain/"},"headline":"State Street Is Testing Blockchain for Securities Lending","url":"http://fortune.com/2016/12/21/state-street-blockchain/","dateCreated":"2016-12-21T19:27:24","datePublished":"2016-12-21T19:27:24","dateModified":"2016-12-21T19:27:24","creator":["Reuters"],"keywords":["blockchain","bitcoin","investors-guide"],"author":["Reuters"],"publisher":{"@type":"Organization","name":"Fortune"},"articleBody":"State Street has tested a blockchain system that it hopes can be used to streamline the securities lending process as the financial industry accelerates efforts to adopt the emerging technology. The software, which was tested this year over the course of seven months, could be chosen as one of the company&#8217;s blockchain projects to be implemented in 2017, Hu Liang, senior managing director of the Emerging Technologies Cen ...
#             (function () {
#               var s = document.createElement('script');
#               s.src = '//cdn.optimizely.com/js/3391221358.js';
#               s.type = 'text/javascript';
#               s.defer = true;
#               var b = document.getElementsByTagName('script')[0];
#               b.parentNode.insertBefore(s,b);
#             })();
#             </script></head><body data-reactid="30"><div data-reactid="31" id="content"><div data-react-checksum="-101222626" data-reactid="1" data-reactroot=""><!-- react-empty: 2 --><div data-reactid="3"><div data-reactid="4"><!-- react-empty: 5 --><!-- react-empty: 6 --><div class="row _2iJc0fdq" data-reactid="7"><div class="column small-12" data-reactid="8"><header class="row _1SLALh47" data-reactid="9"><div class="column small-12" data-reactid="10"><div data-reactid="11"><div class="row _21UDzFnr _2cgpOHNT" data-reactid="12"><div class="column small-12" data-reactid="13"><div data-reactid="14" id="ad-728x90_970x250_970x90_970x66_101x1_1"></div></div></div><div class="row _1LxPsiMb" data-reactid="15"><div class="column small-12" data-reactid="16"><div class="_1zfso-U6" data-reactid="17"><div class="row" data-reactid="18"><div class="column small-6 large-6 medium-4" data-reactid="19"><div class="row" data-reactid="20"><div class="_3htke-Yi" data-reactid="21"><button class="_3TfQUqdk" data-reactid="22"><svg data-reactid="23" height="100%" preserveaspectratio="xMinYMin meet" viewbox="0 0 20 15"><path d="M0,2 20,2" data-reactid="24" stroke-linecap="round" stroke-linejoin="round" stroke-width="1.5"></path><path d="M0,7 20,7" data-reactid="25" stroke-linecap="round" stroke-linejoin="round" stroke-width="1.5"></path><path d="M0,12 20,12" data-reactid="26" stroke-linecap="round" stroke-linejoin="round" stroke-width="1.5"></path></svg></button></div><div class="i-F1CMPw" data-reactid="27"><div class="_1X3LqGF7" data-reactid="28"><a data-reactid="29" href="http://fortune.com/"><svg height="100%" preserveaspectratio="xMinYMin meet" viewbox="0 0 90 21"><path d="M12.1 5.1L12.1 16.3C12.1 18.9 14.2 21 16.9 21 19.5 21 21.6 18.9 21.6 16.3L21.6 5.1C21.6 2.5 19.5 0.4 16.9 0.4L16.9 0.4C14.2 0.4 12.1 2.5 12.1 5.1M15.5 16.3L15.5 5.1C15.5 4.3 16.1 3.8 16.9 3.8L16.9 3.8C17.6 3.8 18.2 4.3 18.2 5.1L18.2 16.3C18.2 17 17.6 17.6 16.9 17.6 16.1 17.6 15.5 17 15.5 16.3"></path><polygon points="49 0.6 39.4 0.6 39.4 4 42.5 4 42.5 20.7 45.9 20.7 45.9 4 49 4"></polygon><path d="M59 0.6L59 16.3C59 17 58.4 17.6 57.7 17.6 57 17.6 56.4 17 56.4 16.3L56.4 0.6 52.9 0.6 52.9 16.3C52.9 18.9 55.1 21 57.7 21 60.3 21 62.5 18.9 62.5 16.3L62.5 0.6 59 0.6Z"></path><polygon points="90.1 4 90.1 0.6 81.7 0.6 81.7 20.7 90.1 20.7 90.1 17.3 85.1 17.3 85.1 12.1 88.3 12.1 88.3 8.7 85.1 8.7 85.1 4"></polygon><path d="M36.2 20.7L32.6 20.7 30.1 11.2C30.1 11.2 32.3 10.8 32.3 8.5L32.3 5.4C32.3 4.6 31.7 4 30.9 4L29.6 4 29.6 20.7 26.2 20.7 26.2 0.6 30.9 0.6C33.5 0.6 35.6 2.6 35.7 5.2L35.7 5.2 35.7 8.4 35.7 8.4C35.7 10.4 35 11.8 33.8 12.8L36.2 20.7Z"></path><polygon points="74.1 0.6 74.1 11.6 70.6 0.6 67.1 0.6 67.1 20.7 70.6 20.7 70.6 10.9 73.8 20.7 77.6 20.7 77.6 0.6"></polygon><polygon points="4.2 0.9 0.9 0.9 0.6 0.9 0.6 21 4.2 21 4.2 12.4 7.5 12.4 7.5 9 4.2 9 4.2 4.3 9.4 4.3 9.4 0.9"></polygon></svg></a></div></div><div class="show-for-medium _19pbYNvm" data-reactid="30"><div class="_2XLp3JbI" data-reactid="31"><a data-reactid="32" href="http://fortune.com/tech"><span class="_3MP1FMky" data-reactid="33">Tech</span></a></div></div></div></div><div class="column small-6 large-6 medium-8" data-reactid="34"><div class="row _268yt6A4" data-reactid="35"><div class="show-for-medium _3vEeJ0XD" data-reactid="36"><div class="column small-12" data-reactid="37"><div class="row _2i6rXEFh" data-reactid="38"><div class="Otl_R8Ar" data-reactid="39"><div data-reactid="40"><a class="_1jYlgGFZ _2UCyZFsr" data-reactid="41" href="#"><svg data-reactid="42" height="18" version="1.1" viewbox="0 0 17 18" width="18"><path d="M10.96 11.28c-2.43 0-4.4-1.98-4.4-4.4 0-2.45 1.97-4.43 4.4-4.43 2.42 0 4.4 1.98 4.4 4.42 0 2.43-1.98 4.4-4.4 4.4m-5.92-4.4c0 1.37.47 2.63 1.26 3.63L.7 16.12c-.34.33-.34.87 0 1.2.16.16.38.24.6.24.22 0 .44-.1.6-.25l5.63-5.6c.96.7 2.15 1.1 3.43 1.1 3.26 0 5.9-2.65 5.9-5.9 0-3.27-2.64-5.93-5.9-5.93-3.26 0-5.92 2.64-5.92 5.9z" data-reactid="43"></path></svg></a><a data-reactid="44" href="#"></a> ...
#               var cb = function() {
#                 var links = [ '/dist/main-55743bf1b908f205f484.css' ];
#                 var h = document.getElementsByTagName('head')[0];
#                 var l, i;
#                 for ( i = 0; i < links.length; i++ ) {
#                   l = document.createElement('link');
#                   l.rel = 'stylesheet';
#                   l.media = 'screen, projection';
#                   l.type = 'text/css';
#                   l.charSet = 'UTF-8';
#                   l.href = links[i];
#                   h.appendChild(l);
#                 }
#               }
#               var raf = requestAnimationFrame || mozRequestAnimationFrame || webkitRequestAnimationFrame || msRequestAnimationFrame;
#               if ( raf ) { raf(cb); } else { window.addEventListener('load', cb); }
#             </script></body></html>

# %%
soup.find('article')
# Out:
# <article class="row" data-reactid="214"><p class="column small-12 medium-10 medium-offset-1 large-offset-2 _10M0Ygc4" data-reactid="215"><a data-reactid="216" href="http://fortune.com/fortune500/state-street-corp-264/" target="_blank"><!-- react-text: 217 -->State Street<!-- /react-text --></a><!-- react-text: 218 --> has tested a blockchain system that it hopes can be used to streamline the securities lending process as the financial industry accelerates efforts to adopt the emerging technology.<!-- /react-text --></p><p class="column small-12 medium-10 medium-offset-1 large-offset-2 _10M0Ygc4" data-reactid="219"><!-- react-text: 220 -->The software, which was tested this year over the course of seven months, could be chosen as one of the company's blockchain projects to be implemented in 2017, Hu Liang, senior managing director of the Emerging Technologies Center at State Street, told Reuters.<!-- /react-text --></p><p class="column small-12 medium-10 medium-offset-1 large-offset-2 _10M0Ygc4" data-reactid="221"><!-- react-text: 222 -->State Street <!-- /react-text --><a class="_11XURygs" data-reactid="223" href="//fortune.com/company/stt"><!-- react-text: 224 -->(<!-- /react-text --><!-- react-text: 225 -->stt<!-- /react-text --><!-- react-text: 226 -->)<!-- /react-text --></a><!-- react-text: 227 --> is one of the largest custodian banks and securities lending providers globally. The blockchain system that it tested would transform the collateral posted by an investor to borrow securities from State Street's clients into a digital token that could be used for other transactions.<!-- /react-text --></p><p class="column small-12 medium-10 medium-offset-1 large-offset-2 _10M0Ygc4" data-reactid="228"><!-- react-text: 229 -->This would create a digital, immutable record of how the collateral had been used and would make it easier and quicker for State Street to return the collateral to the borrower's account once their lending position had been unwound.<!-- /react-text --></p><p class="column small-12 medium-10 medium-offset-1 large-offset-2 _10M0Ygc4" data-reactid="230"><em data-reactid="231"><a data-reactid="232" href="http://fortune.com/getdatasheet/" target="_blank"><!-- react-text: 233 -->Get Data Sheet<!-- /react-text --></a><!-- react-text: 234 -->, <!-- /react-text --></em><!-- react-text: 235 -->Fortune<!-- /react-text --><em data-reactid="236">’s</em><em data-reactid="237"> technology newsletter.</em></p><p class="column small-12 medium-10 medium-offset-1 large-offset-2 _10M0Ygc4" data-reactid="238"><!-- react-text: 239 -->"The aim is to enhance the operational aspect of securities lending," Liang said. "In a lot of cases there is no automated linkage to say which account it (the collateral) should go back to." The system would reduce manual intervention involved with the process, make it faster, and create a better record for regulatory reporting purposes, Liang said.<!-- /react-text --></p><p class="column small-12 medium-10 medium-offset-1 large-offset-2 _10M0Ygc4" data-reactid="240"><!-- react-text: 241 -->The test is one of several blockchain experiments State Street and other financial institutions have been working on over the past year as Wall Street grows increasingly hopeful that the technology, first developed to run cryptocurrency bitcoin, can help them increase efficiency and cut costs.<!-- /react-text --></p><p class="column small-12 medium-10 medium-offset-1 large-offset-2 _10M0Ygc4" data-reactid="242"><!-- react-text: 243 -->Blockchain is a distributed record of transactions that is automatically updated and maintained by a network of computers on the internet, without the need of a trusted third party. Banks and other financial firms have grown convinced that it can be adapted to carry out processes such as the clearing and settlement of securities.<!-- /react-text --></p><p class="column small-12 medium-10 medium-offset-1 large-offset-2 _10M0Ygc4" data-reactid="244"><!-- react-text: 245 -->State Stree ...

# %%
soup.find('article').text
# Out:
# 'State Street has tested a blockchain system that it hopes can be used to streamline the securities lending process as the financial industry accelerates efforts to adopt the emerging technology.The software, which was tested this year over the course of seven months, could be chosen as one of the company\'s blockchain projects to be implemented in 2017, Hu Liang, senior managing director of the Emerging Technologies Center at State Street, told Reuters.State Street (stt) is one of the largest custodian banks and securities lending providers globally. The blockchain system that it tested would transform the collateral posted by an investor to borrow securities from State Street\'s clients into a digital token that could be used for other transactions.This would create a digital, immutable record of how the collateral had been used and would make it easier and quicker for State Street to return the collateral to the borrower\'s account once their lending position had been unwound.Get Data Sheet, Fortune’s technology newsletter."The aim is to enhance the operational aspect of securities lending," Liang said. "In a lot of cases there is no automated linkage to say which account it (the collateral) should go back to." The system would reduce manual intervention involved with the process, make it faster, and create a better record for regulatory reporting purposes, Liang said.The test is one of several blockchain experiments State Street and other financial institutions have been working on over the past year as Wall Street grows increasingly hopeful that the technology, first developed to run cryptocurrency bitcoin, can help them increase efficiency and cut costs.Blockchain is a distributed record of transactions that is automatically updated and maintained by a network of computers on the internet, without the need of a trusted third party. Banks and other financial firms have grown convinced that it can be adapted to carry out processes such as the clearing and settlement of securities.State Street\'s experiment comes as financial firms prepare to bring more blockchain systems out of testing and into implementation in the new year.Brussels-based post trade provider Euroclear announced on Monday it had successfully completed a pilot for a new blockchain-based London bullion settlement service which it expected would go live in 2017.'

# %%
text = ' '.join(map(lambda p: p.text, soup.find_all('article')))

# %%
text
# Out:
# 'State Street has tested a blockchain system that it hopes can be used to streamline the securities lending process as the financial industry accelerates efforts to adopt the emerging technology.The software, which was tested this year over the course of seven months, could be chosen as one of the company\'s blockchain projects to be implemented in 2017, Hu Liang, senior managing director of the Emerging Technologies Center at State Street, told Reuters.State Street (stt) is one of the largest custodian banks and securities lending providers globally. The blockchain system that it tested would transform the collateral posted by an investor to borrow securities from State Street\'s clients into a digital token that could be used for other transactions.This would create a digital, immutable record of how the collateral had been used and would make it easier and quicker for State Street to return the collateral to the borrower\'s account once their lending position had been unwound.Get Data Sheet, Fortune’s technology newsletter."The aim is to enhance the operational aspect of securities lending," Liang said. "In a lot of cases there is no automated linkage to say which account it (the collateral) should go back to." The system would reduce manual intervention involved with the process, make it faster, and create a better record for regulatory reporting purposes, Liang said.The test is one of several blockchain experiments State Street and other financial institutions have been working on over the past year as Wall Street grows increasingly hopeful that the technology, first developed to run cryptocurrency bitcoin, can help them increase efficiency and cut costs.Blockchain is a distributed record of transactions that is automatically updated and maintained by a network of computers on the internet, without the need of a trusted third party. Banks and other financial firms have grown convinced that it can be adapted to carry out processes such as the clearing and settlement of securities.State Street\'s experiment comes as financial firms prepare to bring more blockchain systems out of testing and into implementation in the new year.Brussels-based post trade provider Euroclear announced on Monday it had successfully completed a pilot for a new blockchain-based London bullion settlement service which it expected would go live in 2017.'

# %%
def getTextWaPo(url):
    page = urllib.request.urlopen(url).read().decode('utf8')
    soup = BeautifulSoup(page,"lxml")
    text = ' '.join(map(lambda p: p.text, soup.find_all('article')))
    return text.encode('ascii', errors='replace').replace("?"," ")

# %%
from nltk.tokenize import sent_tokenize,word_tokenize
from nltk.corpus import stopwords
from string import punctuation

# %%
sents = sent_tokenize(text)

# %%
sents
# Out:
# ["State Street has tested a blockchain system that it hopes can be used to streamline the securities lending process as the financial industry accelerates efforts to adopt the emerging technology.The software, which was tested this year over the course of seven months, could be chosen as one of the company's blockchain projects to be implemented in 2017, Hu Liang, senior managing director of the Emerging Technologies Center at State Street, told Reuters.State Street (stt) is one of the largest custodian banks and securities lending providers globally.",
#  "The blockchain system that it tested would transform the collateral posted by an investor to borrow securities from State Street's clients into a digital token that could be used for other transactions.This would create a digital, immutable record of how the collateral had been used and would make it easier and quicker for State Street to return the collateral to the borrower's account once their lending position had been unwound.Get Data Sheet, Fortune’s technology newsletter.",
#  '"The aim is to enhance the operational aspect of securities lending," Liang said.',
#  '"In a lot of cases there is no automated linkage to say which account it (the collateral) should go back to."',
#  'The system would reduce manual intervention involved with the process, make it faster, and create a better record for regulatory reporting purposes, Liang said.The test is one of several blockchain experiments State Street and other financial institutions have been working on over the past year as Wall Street grows increasingly hopeful that the technology, first developed to run cryptocurrency bitcoin, can help them increase efficiency and cut costs.Blockchain is a distributed record of transactions that is automatically updated and maintained by a network of computers on the internet, without the need of a trusted third party.',
#  "Banks and other financial firms have grown convinced that it can be adapted to carry out processes such as the clearing and settlement of securities.State Street's experiment comes as financial firms prepare to bring more blockchain systems out of testing and into implementation in the new year.Brussels-based post trade provider Euroclear announced on Monday it had successfully completed a pilot for a new blockchain-based London bullion settlement service which it expected would go live in 2017."]

# %%
word_sent = word_tokenize(text.lower())

# %%
word_sent
# Out:
# ['state',
#  'street',
#  'has',
#  'tested',
#  'a',
#  'blockchain',
#  'system',
#  'that',
#  'it',
#  'hopes',
#  'can',
#  'be',
#  'used',
#  'to',
#  'streamline',
#  'the',
#  'securities',
#  'lending',
#  'process',
#  'as',
#  'the',
#  'financial',
#  'industry',
#  'accelerates',
#  'efforts',
#  'to',
#  'adopt',
#  'the',
#  'emerging',
#  'technology.the',
#  'software',
#  ',',
#  'which',
#  'was',
#  'tested',
#  'this',
#  'year',
#  'over',
#  'the',
#  'course',
#  'of',
#  'seven',
#  'months',
#  ',',
#  'could',
#  'be',
#  'chosen',
#  'as',
#  'one',
#  'of',
#  'the',
#  'company',
#  "'s",
#  'blockchain',
#  'projects',
#  'to',
#  'be',
#  'implemented',
#  'in',
#  '2017',
#  ',',
#  'hu',
#  'liang',
#  ',',
#  'senior',
#  'managing',
#  'director',
#  'of',
#  'the',
#  'emerging',
#  'technologies',
#  'center',
#  'at',
#  'state',
#  'street',
#  ',',
#  'told',
#  'reuters.state',
#  'street',
#  '(',
#  'stt',
#  ')',
#  'is',
#  'one',
#  'of',
#  'the',
#  'largest',
#  'custodian',
#  'banks',
#  'and',
#  'securities',
#  'lending',
#  'providers',
#  'globally',
#  '.',
#  'the',
#  'blockchain',
#  'system',
#  'that',
#  'it',
#  'tested',
#  'would',
#  'transform',
#  'the',
#  'collateral',
#  'posted',
#  'by',
#  'an',
#  'investor',
#  'to',
#  'borrow',
#  'securities',
#  'from',
#  'state',
#  'street',
#  "'s",
#  'clients',
#  'into',
#  'a',
#  'digital',
#  'token',
#  'that',
#  'could',
#  'be',
#  'used',
#  'for',
#  'other',
#  'transactions.this',
#  'would',
#  'create',
#  'a',
#  'digital',
#  ',',
#  'immutable',
#  'record',
#  'of',
#  'how',
#  'the',
#  'collateral',
#  'had',
#  'been',
#  'used',
#  'and',
#  'would',
#  'make',
#  'it',
#  'easier',
#  'and',
#  'quicker',
#  'for',
#  'state',
#  'street',
#  'to',
#  'return',
#  'the',
#  'collateral',
#  'to',
#  'the',
#  'borrower',
#  "'s",
#  'account',
#  'once',
#  'their',
#  'lending',
#  'position',
#  'had',
#  'been',
#  'unwound.get',
#  'data',
#  'sheet',
#  ',',
#  'fortune’s',
#  'technology',
#  'newsletter',
#  '.',
#  '``',
#  'the',
#  'aim',
#  'is',
#  'to',
#  'enhance',
#  'the',
#  'operational',
#  'aspect',
#  'of',
#  'securities',
#  'lending',
#  ',',
#  "''",
#  'liang',
#  'said',
#  '.',
#  '``',
#  'in',
#  'a',
#  'lot',
#  'of',
#  'cases',
#  'there',
#  'is',
#  'no',
#  'automated',
#  'linkage',
#  'to',
#  'say',
#  'which',
#  'account',
#  'it',
#  '(',
#  'the',
#  'collateral',
#  ')',
#  'should',
#  'go',
#  'back',
#  'to',
#  '.',
#  "''",
#  'the',
#  'system',
#  'would',
#  'reduce',
#  'manual',
#  'intervention',
#  'involved',
#  'with',
#  'the',
#  'process',
#  ',',
#  'make',
#  'it',
#  'faster',
#  ',',
#  'and',
#  'create',
#  'a',
#  'better',
#  'record',
#  'for',
#  'regulatory',
#  'reporting',
#  'purposes',
#  ',',
#  'liang',
#  'said.the',
#  'test',
#  'is',
#  'one',
#  'of',
#  'several',
#  'blockchain',
#  'experiments',
#  'state',
#  'street',
#  'and',
#  'other',
#  'financial',
#  'institutions',
#  'have',
#  'been',
#  'working',
#  'on',
#  'over',
#  'the',
#  'past',
#  'year',
#  'as',
#  'wall',
#  'street',
#  'grows',
#  'increasingly',
#  'hopeful',
#  'that',
#  'the',
#  'technology',
#  ',',
#  'first',
#  'developed',
#  'to',
#  'run',
#  'cryptocurrency',
#  'bitcoin',
#  ',',
#  'can',
#  'help',
#  'them',
#  'increase',
#  'efficiency',
#  'and',
#  'cut',
#  'costs.blockchain',
#  'is',
#  'a',
#  'distributed',
#  'record',
#  'of',
#  'transactions',
#  'that',
#  'is',
#  'automatically',
#  'updated',
#  'and',
#  'maintained',
#  'by',
#  'a',
#  'network',
#  'of',
#  'computers',
#  'on',
#  'the',
#  'internet',
#  ',',
#  'without',
#  'the',
#  'need',
#  'of',
#  'a',
#  'trusted',
#  'third',
#  'party',
#  '.',
#  'banks',
#  'and',
#  'other',
#  'financial',
#  'firms',
#  'have',
#  'grown',
#  'convinced',
#  'that',
#  'it',
#  'can',
#  'be',
#  'adapted',
#  'to',
#  'carry',
#  'out',
#  'processes',
#  'such',
#  'as',
#  'the',
#  'clearing',
#  'and',
#  'settlement',
#  'of',
#  'securities.state',
#  'street',
#  "'s",
#  'experiment',
#  'comes',
#  'as',
#  'financial',
#  'firms',
#  'prepare',
#  'to',
#  'bring',
#  'more',
#  'blockchain',
#  'systems',
#  'out',
#  'of',
#  'testing',
#  'and',
#  'into',
#  'implementation',
#  'in',
#  'the',
#  'new',
#  'year.brussels-based',
#  'post',
#  'trade',
#  'provider',
#  'euroclear',
#  'announced',
#  'on',
#  'monday',
#  'it',
#  'had',
#  'successfully',
#  'completed',
#  'a',
#  'pilot',
#  'for',
#  'a',
#  'new',
#  'blockchain-based',
#  'london',
#  'bullion',
#  'settlement',
#  'service',
#  'which',
#  'it',
#  'expected',
#  'would',
#  'go',
#  'live',
#  'in',
#  '2017',
#  '.']

# %%
_stopwords = set(stopwords.words('english') + list(punctuation))

# %%
_stopwords
# Out:
# {'!',
#  '"',
#  '#',
#  '$',
#  '%',
#  '&',
#  "'",
#  '(',
#  ')',
#  '*',
#  '+',
#  ',',
#  '-',
#  '.',
#  '/',
#  ':',
#  ';',
#  '<',
#  '=',
#  '>',
#  '?',
#  '@',
#  '[',
#  '\\',
#  ']',
#  '^',
#  '_',
#  '`',
#  'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  'd',
#  'did',
#  'didn',
#  'do',
#  'does',
#  'doesn',
#  'doing',
#  'don',
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  'has',
#  'hasn',
#  'have',
#  'haven',
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  'it',
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  'more',
#  'most',
#  'mustn',
#  'my',
#  'myself',
#  'needn',
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  'she',
#  'should',
#  'shouldn',
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  'we',
#  'were',
#  'weren',
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  'wouldn',
#  'y',
#  'you',
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  '{',
#  '|',
#  '}',
#  '~'}

# %%
word_sent=[word for word in word_sent if word not in _stopwords]

# %%
word_sent
# Out:
# ['state',
#  'street',
#  'tested',
#  'blockchain',
#  'system',
#  'hopes',
#  'used',
#  'streamline',
#  'securities',
#  'lending',
#  'process',
#  'financial',
#  'industry',
#  'accelerates',
#  'efforts',
#  'adopt',
#  'emerging',
#  'technology.the',
#  'software',
#  'tested',
#  'year',
#  'course',
#  'seven',
#  'months',
#  'could',
#  'chosen',
#  'one',
#  'company',
#  "'s",
#  'blockchain',
#  'projects',
#  'implemented',
#  '2017',
#  'hu',
#  'liang',
#  'senior',
#  'managing',
#  'director',
#  'emerging',
#  'technologies',
#  'center',
#  'state',
#  'street',
#  'told',
#  'reuters.state',
#  'street',
#  'stt',
#  'one',
#  'largest',
#  'custodian',
#  'banks',
#  'securities',
#  'lending',
#  'providers',
#  'globally',
#  'blockchain',
#  'system',
#  'tested',
#  'would',
#  'transform',
#  'collateral',
#  'posted',
#  'investor',
#  'borrow',
#  'securities',
#  'state',
#  'street',
#  "'s",
#  'clients',
#  'digital',
#  'token',
#  'could',
#  'used',
#  'transactions.this',
#  'would',
#  'create',
#  'digital',
#  'immutable',
#  'record',
#  'collateral',
#  'used',
#  'would',
#  'make',
#  'easier',
#  'quicker',
#  'state',
#  'street',
#  'return',
#  'collateral',
#  'borrower',
#  "'s",
#  'account',
#  'lending',
#  'position',
#  'unwound.get',
#  'data',
#  'sheet',
#  'fortune’s',
#  'technology',
#  'newsletter',
#  '``',
#  'aim',
#  'enhance',
#  'operational',
#  'aspect',
#  'securities',
#  'lending',
#  "''",
#  'liang',
#  'said',
#  '``',
#  'lot',
#  'cases',
#  'automated',
#  'linkage',
#  'say',
#  'account',
#  'collateral',
#  'go',
#  'back',
#  "''",
#  'system',
#  'would',
#  'reduce',
#  'manual',
#  'intervention',
#  'involved',
#  'process',
#  'make',
#  'faster',
#  'create',
#  'better',
#  'record',
#  'regulatory',
#  'reporting',
#  'purposes',
#  'liang',
#  'said.the',
#  'test',
#  'one',
#  'several',
#  'blockchain',
#  'experiments',
#  'state',
#  'street',
#  'financial',
#  'institutions',
#  'working',
#  'past',
#  'year',
#  'wall',
#  'street',
#  'grows',
#  'increasingly',
#  'hopeful',
#  'technology',
#  'first',
#  'developed',
#  'run',
#  'cryptocurrency',
#  'bitcoin',
#  'help',
#  'increase',
#  'efficiency',
#  'cut',
#  'costs.blockchain',
#  'distributed',
#  'record',
#  'transactions',
#  'automatically',
#  'updated',
#  'maintained',
#  'network',
#  'computers',
#  'internet',
#  'without',
#  'need',
#  'trusted',
#  'third',
#  'party',
#  'banks',
#  'financial',
#  'firms',
#  'grown',
#  'convinced',
#  'adapted',
#  'carry',
#  'processes',
#  'clearing',
#  'settlement',
#  'securities.state',
#  'street',
#  "'s",
#  'experiment',
#  'comes',
#  'financial',
#  'firms',
#  'prepare',
#  'bring',
#  'blockchain',
#  'systems',
#  'testing',
#  'implementation',
#  'new',
#  'year.brussels-based',
#  'post',
#  'trade',
#  'provider',
#  'euroclear',
#  'announced',
#  'monday',
#  'successfully',
#  'completed',
#  'pilot',
#  'new',
#  'blockchain-based',
#  'london',
#  'bullion',
#  'settlement',
#  'service',
#  'expected',
#  'would',
#  'go',
#  'live',
#  '2017']

# %%
from nltk.probability import FreqDist

# %%
freq = FreqDist(word_sent)

# %%
freq
# Out:
# FreqDist({"''": 2,
#           "'s": 4,
#           '2017': 2,
#           '``': 2,
#           'accelerates': 1,
#           'account': 2,
#           'adapted': 1,
#           'adopt': 1,
#           'aim': 1,
#           'announced': 1,
#           'aspect': 1,
#           'automated': 1,
#           'automatically': 1,
#           'back': 1,
#           'banks': 2,
#           'better': 1,
#           'bitcoin': 1,
#           'blockchain': 5,
#           'blockchain-based': 1,
#           'borrow': 1,
#           'borrower': 1,
#           'bring': 1,
#           'bullion': 1,
#           'carry': 1,
#           'cases': 1,
#           'center': 1,
#           'chosen': 1,
#           'clearing': 1,
#           'clients': 1,
#           'collateral': 4,
#           'comes': 1,
#           'company': 1,
#           'completed': 1,
#           'computers': 1,
#           'convinced': 1,
#           'costs.blockchain': 1,
#           'could': 2,
#           'course': 1,
#           'create': 2,
#           'cryptocurrency': 1,
#           'custodian': 1,
#           'cut': 1,
#           'data': 1,
#           'developed': 1,
#           'digital': 2,
#           'director': 1,
#           'distributed': 1,
#           'easier': 1,
#           'efficiency': 1,
#           'efforts': 1,
#           'emerging': 2,
#           'enhance': 1,
#           'euroclear': 1,
#           'expected': 1,
#           'experiment': 1,
#           'experiments': 1,
#           'faster': 1,
#           'financial': 4,
#           'firms': 2,
#           'first': 1,
#           'fortune’s': 1,
#           'globally': 1,
#           'go': 2,
#           'grown': 1,
#           'grows': 1,
#           'help': 1,
#           'hopeful': 1,
#           'hopes': 1,
#           'hu': 1,
#           'immutable': 1,
#           'implementation': 1,
#           'implemented': 1,
#           'increase': 1,
#           'increasingly': 1,
#           'industry': 1,
#           'institutions': 1,
#           'internet': 1,
#           'intervention': 1,
#           'investor': 1,
#           'involved': 1,
#           'largest': 1,
#           'lending': 4,
#           'liang': 3,
#           'linkage': 1,
#           'live': 1,
#           'london': 1,
#           'lot': 1,
#           'maintained': 1,
#           'make': 2,
#           'managing': 1,
#           'manual': 1,
#           'monday': 1,
#           'months': 1,
#           'need': 1,
#           'network': 1,
#           'new': 2,
#           'newsletter': 1,
#           'one': 3,
#           'operational': 1,
#           'party': 1,
#           'past': 1,
#           'pilot': 1,
#           'position': 1,
#           'post': 1,
#           'posted': 1,
#           'prepare': 1,
#           'process': 2,
#           'processes': 1,
#           'projects': 1,
#           'provider': 1,
#           'providers': 1,
#           'purposes': 1,
#           'quicker': 1,
#           'record': 3,
#           'reduce': 1,
#           'regulatory': 1,
#           'reporting': 1,
#           'return': 1,
#           'reuters.state': 1,
#           'run': 1,
#           'said': 1,
#           'said.the': 1,
#           'say': 1,
#           'securities': 4,
#           'securities.state': 1,
#           'senior': 1,
#           'service': 1,
#           'settlement': 2,
#           'seven': 1,
#           'several': 1,
#           'sheet': 1,
#           'software': 1,
#           'state': 5,
#           'streamline': 1,
#           'street': 8,
#           'stt': 1,
#           'successfully': 1,
#           'system': 3,
#           'systems': 1,
#           'technologies': 1,
#           'technology': 2,
#           'technology.the': 1,
#           'test': 1,
#           'tested': 3,
#           'testing': 1,
#           'third': 1,
#           'token': 1,
#           'told': 1,
#           'trade': 1,
#           'transactions': 1,
#           'transactions.this': 1,
#           'transform': 1,
#           'trusted': 1,
#           'unwound.get': 1,
#           'updated': 1,
#           'used': 3,
#           'wall': 1,
#           'without': 1,
#           'working': 1,
#           'would': 5,
#           'year': 2,
#           'year.brussels-based': 1})

# %%
from heapq import nlargest

# %%
nlargest(10, freq, key=freq.get)
# Out:
# ['street',
#  'would',
#  'blockchain',
#  'state',
#  'lending',
#  'collateral',
#  'financial',
#  "'s",
#  'securities',
#  'tested']

# %%
from collections import defaultdict
ranking = defaultdict(int)

for i,sent in enumerate(sents):
    for w in word_tokenize(sent.lower()):
        if w in freq:
            ranking[i] += freq[w]
            
ranking
# Out:
# defaultdict(int, {0: 131, 1: 121, 2: 20, 3: 18, 4: 103, 5: 78})

# %%
sents_idx = nlargest(4, ranking, key=ranking.get)

# %%
sents_idx
# Out:
# [0, 1, 4, 5]

# %%
[sents[j] for j in sorted(sents_idx)]
# Out:
# ["State Street has tested a blockchain system that it hopes can be used to streamline the securities lending process as the financial industry accelerates efforts to adopt the emerging technology.The software, which was tested this year over the course of seven months, could be chosen as one of the company's blockchain projects to be implemented in 2017, Hu Liang, senior managing director of the Emerging Technologies Center at State Street, told Reuters.State Street (stt) is one of the largest custodian banks and securities lending providers globally.",
#  "The blockchain system that it tested would transform the collateral posted by an investor to borrow securities from State Street's clients into a digital token that could be used for other transactions.This would create a digital, immutable record of how the collateral had been used and would make it easier and quicker for State Street to return the collateral to the borrower's account once their lending position had been unwound.Get Data Sheet, Fortune’s technology newsletter.",
#  'The system would reduce manual intervention involved with the process, make it faster, and create a better record for regulatory reporting purposes, Liang said.The test is one of several blockchain experiments State Street and other financial institutions have been working on over the past year as Wall Street grows increasingly hopeful that the technology, first developed to run cryptocurrency bitcoin, can help them increase efficiency and cut costs.Blockchain is a distributed record of transactions that is automatically updated and maintained by a network of computers on the internet, without the need of a trusted third party.',
#  "Banks and other financial firms have grown convinced that it can be adapted to carry out processes such as the clearing and settlement of securities.State Street's experiment comes as financial firms prepare to bring more blockchain systems out of testing and into implementation in the new year.Brussels-based post trade provider Euroclear announced on Monday it had successfully completed a pilot for a new blockchain-based London bullion settlement service which it expected would go live in 2017."]

# %%
def summarize(text, n):
    sents = sent_tokenize(text)
    
    assert n <= len(sents)
    word_sent = word_tokenize(text.lower())
    _stopwords = set(stopwords.words('english') + list(punctuation))
    
    word_sent=[word for word in word_sent if word not in _stopwords]
    freq = FreqDist(word_sent)
    
    
    ranking = defaultdict(int)
    
    for i,sent in enumerate(sents):
        for w in word_tokenize(sent.lower()):
            if w in freq:
                ranking[i] += freq[w]
             
        
    sents_idx = nlargest(n, ranking, key=ranking.get)
    return [sents[j] for j in sorted(sents_idx)]

# %%
summarize(text, 2)
# Out:
# ["State Street has tested a blockchain system that it hopes can be used to streamline the securities lending process as the financial industry accelerates efforts to adopt the emerging technology.The software, which was tested this year over the course of seven months, could be chosen as one of the company's blockchain projects to be implemented in 2017, Hu Liang, senior managing director of the Emerging Technologies Center at State Street, told Reuters.State Street (stt) is one of the largest custodian banks and securities lending providers globally.",
#  "The blockchain system that it tested would transform the collateral posted by an investor to borrow securities from State Street's clients into a digital token that could be used for other transactions.This would create a digital, immutable record of how the collateral had been used and would make it easier and quicker for State Street to return the collateral to the borrower's account once their lending position had been unwound.Get Data Sheet, Fortune’s technology newsletter."]
